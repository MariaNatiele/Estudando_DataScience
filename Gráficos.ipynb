# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaNatiele/Estudando_DataScience/blob/main/Gr%C3%A1ficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Gráficos  com Python
# 1. Histograma
# 2. Densidade
# 3. Depressão
# 4. Disperssão
# 5. Boxplot
# 6. Barras e setores
# 7. Boxplot com Seabron
# 8. Histograma e Densidade com Seabron
# 9. Gráficos Disperssão com Seabron
# 10. Gráficos em 3D

# %%
#Importanado as bibliotecas gráficos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Base dados
dataframe = pd.read_csv("trees.csv")
dataframe.shape
# Out:
# (31, 3)

# %%
dataframe.head(5)
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
#iloc[,1] seleciona a coluna Height - > Altura; bins= 6 -> Quantidade de eixos
histograma = np.histogram(dataframe.iloc[:,1],bins= 6 )
histograma
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
#gerando o gráfico

plt.hist(dataframe.iloc[:,1],bins=6)
plt.title("Histograma")
plt.xlabel("Altura")
plt.ylabel("Frequência")
# Out:
# Text(0, 0.5, 'Frequência')

# %% [markdown]
# Gráfico de Densidade

# %%
#histograma no Seaborn
sns.histplot(dataframe.iloc[:,1],kde=False, bins=6, color="Blue" ).set(title = ("Arvore"))
# Out:
# [Text(0.5, 1.0, 'Arvore')]

# %%
sns.kdeplot(dataframe.iloc[:,1],color="Blue" ).set(title = ("Arvore"))
# Out:
# [Text(0.5, 1.0, 'Arvore')]

# %%
#Kde true -> une o hist kdeplot
sns.histplot(dataframe.iloc[:,1],kde=True, bins=6, color="Blue" ).set(title = ("Arvore"))
# Out:
# [Text(0.5, 1.0, 'Arvore')]

# %% [markdown]
# Gráfico dispersão

# %%
#marker="."  aparece como icone no gráfico
plt.scatter(x=dataframe.Girth, y=dataframe.Volume, color="green", facecolors="none", marker="." )
plt.title("Arvore")
plt.xlabel("Circunferencia")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
plt.plot(dataframe.Girth,dataframe.Volume)
plt.title("Arvore")
plt.xlabel("Circunferencia")
plt.ylabel("Volume")
# Out:
# Text(0, 0.5, 'Volume')

# %%
#gráfico de disperssão no seaborn
#dá aleatoriedade as dados -> x_jitter = 0.3; 
# Linha de tendência -> fit_reg = True
sns.regplot(x=dataframe.Girth, y=dataframe.Volume, data = dataframe, x_jitter = 0.3, fit_reg = True)
# Out:
# <Axes: xlabel='Girth', ylabel='Volume'>

# %% [markdown]
# Gráfico de dispersão com legenda

# %%
dados = pd.read_csv("co2.csv")
dados.shape
# Out:
# (84, 5)

# %%
dados.head(5)
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
#selecionando as variaveis
x = dados.conc
y = dados.uptake

# %%
#lista dos valores unicos de dataframe.Treatment
unicos = list(set(dados.Treatment))
unicos
# Out:
# ['nonchilled', 'chilled']

# %%
#gráfico
for i in range(len(unicos)):
  indice = dados.Treatment == unicos[i]
  plt.scatter(x[indice], y[indice], label = unicos[1])
plt.legend(loc="lower right")

# %% [markdown]
# Divisão de tela

# %%
dataframe.head(3)
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2

# %%
#gráfico de disperssão  Circunferencia -> Girth e Volume
plt.scatter(dataframe.Girth, dataframe.Volume);

# %%
#circunferencia -> Girth e a Altura
plt.scatter(dataframe.Girth, dataframe.Height);

# %%
#Altura -> Height e o  Volume
plt.scatter(dataframe.Height, dataframe.Volume);

# %%
#hist Volume

plt.hist(dataframe.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %%
#Unindo todos os gráficos
#plt.subplot(2,2,4) 2: Linhas, 2: Colunas, 4: Posição
plt.figure(1)
plt.subplot(2,2,1)
plt.scatter(dataframe.Girth, dataframe.Volume)
plt.subplot(2,2,2)
plt.scatter(dataframe.Girth, dataframe.Height)
plt.subplot(2,2,3)
plt.scatter(dataframe.Height, dataframe.Volume, marker="*")
plt.subplot(2,2,4)

plt.hist(dataframe.Volume);

# %% [markdown]
# Boxplot

# %%
#notch=True -> detalhe proximo a mediana; showfliers -> desconsidera o outilier
plt.boxplot(dataframe.Volume, vert=False, showfliers=False, notch=True, patch_artist=True)
plt.title("Arvore")
plt.xlabel("Volume")
# Out:
# Text(0.5, 0, 'Volume')

# %%
plt.boxplot(dataframe)
plt.title("Arvore")
plt.xlabel("Dados")
# Out:
# Text(0.5, 0, 'Dados')

# %%
plt.boxplot(dataframe.Girth, vert=False)
plt.boxplot(dataframe.Volume, vert=False)
plt.boxplot(dataframe.Height, vert=False)


plt.title("Arvore")
plt.xlabel("Dados")
# Out:
# Text(0.5, 0, 'Dados')

# %% [markdown]
# Gráfico Barras e Setores
